# %% [markdown]
# <a href="https://colab.research.google.com/github/datacentertugaskuliah-coder/PraktekJST/blob/main/PROGRAM_ANALISIS_GENOM_MITOKONDRIA_DENGAN_BIDIRECTIONAL_RNN_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================================
# PROGRAM ANALISIS GENOM MITOKONDRIA DENGAN BIDIRECTIONAL RNN-LSTM
# ====================================================================
# Judul       : Implementasi Bi-LSTM untuk Klasifikasi Wilayah Coding pada
#               Genom Mitokondria Channa micropeltes (KX129904)
# Deskripsi   : Program ini melakukan pengambilan data dari NCBI (3 mode),
#               eksplorasi data (EDA), preprocessing dengan sliding window,
#               augmentasi forward & reverse complement + random substitution,
#               penyeimbangan SMOTE, pelatihan CNN-BiLSTM dengan regularisasi kuat,
#               evaluasi metrik (akurasi, precision, recall, F1, AUC) menggunakan sklearn,
#               serta deployment pada 5 sekuens uji.
#               Durasi komputasi dirancang antara 5–10 menit di GPU Google Colab.
# Penulis     : Berdasarkan analisis kritis dan perbaikan logis (anti-overfitting)
# Versi       : Final (1 Cell) – Standar jurnal internasional Q1–Q4
# ====================================================================

# -------------------- 1. PERSIAPAN LINGKUNGAN --------------------
# !pip install -q biopython imbalanced-learn joblib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_recall_fscore_support
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, regularizers
from Bio import Entrez, SeqIO
from Bio.Seq import Seq
import joblib
import os
import time
import warnings
warnings.filterwarnings('ignore')

# Reproduksibilitas
np.random.seed(42)
tf.random.set_seed(42)

print("✅ Lingkungan siap | TensorFlow version:", tf.__version__)

# -------------------- 2. FUNGSI UTILITAS (TERKOREKSI + AUGMENTASI) --------------------
def validate_sequence(seq):
    """Memastikan sekuens hanya berisi A, T, C, G dan panjang memadai."""
    if not isinstance(seq, str):
        raise ValueError("Sekuens harus berupa string.")
    seq = seq.upper()
    if not set(seq).issubset('ATCG'):
        raise ValueError(f"Karakter tidak valid: {set(seq) - set('ATCG')}")
    if len(seq) < 100:
        raise ValueError(f"Panjang sekuens ({len(seq)} bp) terlalu pendek.")
    return seq

def one_hot_encode(seq):
    """One-hot encoding (4 dimensi) untuk sekuens DNA."""
    mapping = {'A':[1,0,0,0], 'T':[0,1,0,0], 'C':[0,0,1,0], 'G':[0,0,0,1]}
    return np.array([mapping.get(b, [0,0,0,0]) for b in seq])

def sliding_windows(seq, window=1000, stride=500):
    """Membagi sekuens menjadi jendela-jendela yang saling tumpang tindih."""
    if window > len(seq):
        raise ValueError(f"Window ({window}) > panjang sekuens ({len(seq)}).")
    windows = []
    for start in range(0, len(seq) - window + 1, stride):
        windows.append(one_hot_encode(seq[start:start+window]))
    if not windows:
        raise ValueError("Tidak ada window yang dihasilkan.")
    return np.array(windows)

def random_substitution_augmentation(windows, mutation_rate=0.01):
    """Melakukan augmentasi dengan substitusi acak sejumlah mutation_rate persen basa per window.
       Input: array windows (n_windows, window_size, 4)
       Output: array windows_augmented (n_windows, window_size, 4) dengan mutasi."""
    windows_aug = windows.copy()
    n_windows, win_len, _ = windows_aug.shape
    n_mutations = max(1, int(win_len * mutation_rate))
    for i in range(n_windows):
        # Pilih posisi acak untuk dimutasi
        positions = np.random.choice(win_len, size=n_mutations, replace=False)
        for pos in positions:
            # Ubah one-hot encoding menjadi basa acak (A, T, C, G) dengan probabilitas sama
            new_base = np.random.choice(4)
            windows_aug[i, pos] = [0,0,0,0]
            windows_aug[i, pos, new_base] = 1
    return windows_aug

def gc_content(seq):
    """Proporsi GC (dalam 0..1)."""
    if not seq:
        return 0.0
    seq = seq.upper()
    return (seq.count('G') + seq.count('C')) / len(seq)

def reverse_coordinates(coding_regions, seq_length):
    """Mengubah koordinat CDS untuk sekuens reverse complement (0-indexed)."""
    return [(seq_length - end, seq_length - start) for (start, end) in coding_regions]

def label_from_annotations(sequence, coding_regions, window=1000, stride=500):
    """Buat label (1 = coding) berdasarkan overlap dengan CDS (0-indexed)."""
    if not coding_regions:
        raise ValueError("Daftar CDS kosong.")
    starts = list(range(0, len(sequence) - window + 1, stride))
    labels = []
    for start in starts:
        win_start, win_end = start, start + window
        overlap = any(max(win_start, cds[0]) < min(win_end, cds[1]) for cds in coding_regions)
        labels.append(1 if overlap else 0)
    labels = np.array(labels)
    if len(np.unique(labels)) == 1:
        print("⚠️ Peringatan: Label anotasi hanya satu kelas, beralih ke GC content.")
        return label_from_gc(sequence, window, stride)
    return labels

def label_from_gc(sequence, window=1000, stride=500):
    """Label berdasarkan median GC content per jendela."""
    windows = [sequence[i:i+window] for i in range(0, len(sequence)-window+1, stride)]
    gc_vals = [gc_content(w) for w in windows]
    threshold = np.median(gc_vals)
    labels = (np.array(gc_vals) > threshold).astype(int)
    if len(np.unique(labels)) == 1:
        threshold = np.mean(gc_vals)
        labels = (np.array(gc_vals) > threshold).astype(int)
    return labels

def fetch_fasta(accession, email="user@example.com"):
    Entrez.email = email
    try:
        handle = Entrez.efetch(db="nucleotide", id=accession, rettype="fasta", retmode="text")
        record = SeqIO.read(handle, "fasta")
        handle.close()
        return str(record.seq).upper(), None
    except Exception as e:
        print(f"❌ Gagal fetch FASTA: {e}")
        return None, None

def fetch_genbank(accession, email="user@example.com"):
    Entrez.email = email
    try:
        handle = Entrez.efetch(db="nucleotide", id=accession, rettype="gb", retmode="text")
        record = SeqIO.read(handle, "genbank")
        handle.close()
        seq = str(record.seq).upper()
        coding = []
        for feat in record.features:
            if feat.type == "CDS":
                start = feat.location.start.position
                end = feat.location.end.position
                coding.append((start, end))
        return seq, coding
    except Exception as e:
        print(f"❌ Gagal fetch GenBank: {e}")
        return None, None

def synthetic_sequence(length=16567):
    bases = ['A','T','C','G']
    probs = [0.3254, 0.2582, 0.2759, 0.1405]
    return ''.join(np.random.choice(bases, size=length, p=probs))

# -------------------- 3. PEMILIHAN MODE DATASET --------------------
ACCESSION = "KX129904"
print("\n" + "="*60)
print("📥 LOAD DATASET DARI NCBI")
print(f"URL: https://www.ncbi.nlm.nih.gov/nuccore/{ACCESSION}")
print("="*60)
print("\nPilih mode pengambilan data:")
print("1️⃣  Mode Cepat (FASTA only) → label berdasarkan GC content")
print("2️⃣  Mode Lengkap (FASTA + Anotasi) → label berdasarkan CDS (DIREKOMENDASIKAN)")
print("3️⃣  Mode Offline (Fallback) → data sintetis")

mode = input("\nMasukkan pilihan (1/2/3): ").strip()

sequence = None
coding_regions = None
label_method = None

try:
    if mode == "1":
        print("\n🔹 Mode 1: Mengambil FASTA...")
        sequence, _ = fetch_fasta(ACCESSION)
        if sequence:
            sequence = validate_sequence(sequence)
            print(f"✅ Sekuens valid, panjang = {len(sequence)} bp")
            label_method = "gc"
        else:
            raise Exception("Fallback ke mode sintetis")
    elif mode == "2":
        print("\n🔹 Mode 2: Mengambil FASTA + Anotasi (koordinat 0-indexed)...")
        sequence, coding_regions = fetch_genbank(ACCESSION)
        if sequence and coding_regions:
            sequence = validate_sequence(sequence)
            print(f"✅ Sekuens valid ({len(sequence)} bp), {len(coding_regions)} CDS ditemukan.")
            print(f"   Contoh CDS pertama: {coding_regions[0]}")
            label_method = "annotation"
        else:
            raise Exception("Fallback ke mode sintetis")
    else:
        print("\n🔹 Mode 3: Menggunakan data sintetis...")
        sequence = synthetic_sequence()
        sequence = validate_sequence(sequence)
        print(f"✅ Sekuens sintetis dibuat, panjang = {len(sequence)} bp")
        label_method = "gc"
except Exception as e:
    print(f"⚠️ Error: {e}. Menggunakan data sintetis sebagai fallback final.")
    sequence = synthetic_sequence()
    sequence = validate_sequence(sequence)
    label_method = "gc"

print(f"\n📌 Metode label yang digunakan: {label_method}")

# -------------------- 4. EKSPLORASI DATA (EDA) – STANDAR INTERNASIONAL --------------------
print("\n" + "="*60)
print("📊 EKSPLORASI DATA AWAL (EDA)")
print("="*60)

total_len = len(sequence)
counts = {base: sequence.count(base) for base in 'ATCG'}
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle("Analisis Eksplorasi Genom Mitokondria Channa micropeltes", fontsize=14)

axes[0,0].pie(counts.values(), labels=counts.keys(), autopct='%1.1f%%', startangle=90)
axes[0,0].set_title("Komposisi Nukleotida (seluruh genom)")

windows_seq = [sequence[i:i+1000] for i in range(0, len(sequence)-999, 500)]
gc_windows = [gc_content(w) for w in windows_seq]
axes[0,1].hist(gc_windows, bins=30, edgecolor='black', alpha=0.7)
axes[0,1].axvline(np.median(gc_windows), color='red', linestyle='--', label=f'Median={np.median(gc_windows):.3f}')
axes[0,1].set_title("Distribusi GC Content per Window (1000 bp)")
axes[0,1].set_xlabel("GC Content"); axes[0,1].set_ylabel("Frekuensi"); axes[0,1].legend()

axes[1,0].boxplot(gc_windows, vert=True)
axes[1,0].set_title("Boxplot GC Content")
axes[1,0].set_ylabel("GC Content")
axes[1,0].set_xticklabels(['Window'])

from sklearn.feature_extraction.text import CountVectorizer
vec = CountVectorizer(analyzer='char', vocabulary=['A','T','C','G'])
X_counts = vec.fit_transform(windows_seq[:100]).toarray()
corr = np.corrcoef(X_counts.T)
sns.heatmap(corr, annot=True, xticklabels=['A','T','C','G'], yticklabels=['A','T','C','G'], ax=axes[1,1], cmap='coolwarm')
axes[1,1].set_title("Korelasi Frekuensi Basa per Window")

plt.tight_layout()
plt.show()

temp_labels = label_from_gc(sequence, 1000, 500) if label_method == "gc" else label_from_annotations(sequence, coding_regions, 1000, 500)
unique, counts_class = np.unique(temp_labels, return_counts=True)
plt.figure(figsize=(6,4))
plt.bar(['Non-Coding (0)', 'Coding (1)'], counts_class, color=['skyblue', 'salmon'])
plt.title("Distribusi Kelas Awal (Sebelum Balancing)")
plt.ylabel("Jumlah Window")
for i, v in enumerate(counts_class):
    plt.text(i, v+5, str(v), ha='center')
plt.show()
print(f"Distribusi kelas awal: 0={counts_class[0]}, 1={counts_class[1]}")

# -------------------- 5. PREPROCESSING & AUGMENTASI DENGAN KOREKSI KOORDINAT --------------------
WINDOW = 1000
STRIDE = 500

X_fwd = sliding_windows(sequence, WINDOW, STRIDE)
if label_method == "annotation":
    y_fwd = label_from_annotations(sequence, coding_regions, WINDOW, STRIDE)
else:
    y_fwd = label_from_gc(sequence, WINDOW, STRIDE)

rev_seq = str(Seq(sequence).reverse_complement())
if label_method == "annotation":
    rev_coding_regions = reverse_coordinates(coding_regions, len(sequence))
    y_rev = label_from_annotations(rev_seq, rev_coding_regions, WINDOW, STRIDE)
else:
    y_rev = label_from_gc(rev_seq, WINDOW, STRIDE)

X_rev = sliding_windows(rev_seq, WINDOW, STRIDE)

# Gabungkan data asli (forward + reverse)
X = np.vstack([X_fwd, X_rev])
y = np.concatenate([y_fwd, y_rev])

# AUGMENTASI TAMBAHAN: random substitution 1% untuk setiap window (double data)
X_aug = random_substitution_augmentation(X, mutation_rate=0.01)
y_aug = y.copy()  # label tetap sama karena mutasi acak tidak mengubah fungsi biologis secara signifikan

X = np.vstack([X, X_aug])
y = np.concatenate([y, y_aug])

print(f"Total data setelah augmentasi (reverse complement + random sub): {X.shape[0]} sampel")
print(f"Distribusi label: 0={np.sum(y==0)}, 1={np.sum(y==1)}")

if len(np.unique(y)) == 1:
    print("⚠️ Hanya satu kelas, memaksa threshold berbeda.")
    new_labels = []
    for win in X:
        gc_win = np.mean(win[:,2] + win[:,3])
        new_labels.append(1 if gc_win > 0.4 else 0)
    y = np.array(new_labels)
    print(f"Setelah koreksi: 0={np.sum(y==0)}, 1={np.sum(y==1)}")

# -------------------- 6. PENYEIMBANGAN DENGAN SMOTE --------------------
n_samp, win_len, n_feat = X.shape
X_flat = X.reshape(n_samp, -1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_flat)

if len(np.unique(y)) > 1 and np.min(np.bincount(y)) < 0.4 * len(y):
    smote = SMOTE(random_state=42)
    X_bal, y_bal = smote.fit_resample(X_scaled, y)
    print(f"SMOTE diterapkan: {X_bal.shape[0]} sampel.")
else:
    X_bal, y_bal = X_scaled, y
    print("Data sudah seimbang, SMOTE tidak diperlukan.")

X_bal = X_bal.reshape(-1, win_len, n_feat)

try:
    X_train, X_test, y_train, y_test = train_test_split(X_bal, y_bal, test_size=0.2,
                                                        random_state=42, stratify=y_bal)
except ValueError:
    X_train, X_test, y_train, y_test = train_test_split(X_bal, y_bal, test_size=0.2,
                                                        random_state=42)
    print("⚠️ Stratifikasi gagal, menggunakan split biasa.")

# Pastikan label berbentuk 1D
y_train = y_train.astype(int).flatten()
y_test = y_test.astype(int).flatten()

print(f"Data latih: {X_train.shape[0]}, data uji: {X_test.shape[0]}")
print(f"Label latih: 0={np.sum(y_train==0)}, 1={np.sum(y_train==1)}")

# Validasi ukuran data training
if X_train.shape[0] < 2:
    raise RuntimeError("Data latih terlalu kecil (<2 sampel). Coba perbesar window/stride atau gunakan mode lain.")

# -------------------- 7. ARSITEKTUR CNN-BiLSTM DENGAN REGULARISASI KUAT (ANTI-OVERFITTING) --------------------
def build_model(input_shape):
    inputs = layers.Input(shape=input_shape)
    # Layer konvolusi dengan dropout tinggi
    x = layers.Conv1D(32, 5, padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-3))(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Dropout(0.5)(x)

    x = layers.Conv1D(64, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-3))(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(2)(x)
    x = layers.Dropout(0.5)(x)

    # Bidirectional LSTM dengan unit lebih kecil dan dropout tinggi
    x = layers.Bidirectional(layers.LSTM(32, return_sequences=True,
                                         dropout=0.3, recurrent_dropout=0.3,
                                         kernel_regularizer=regularizers.l2(1e-3)))(x)
    x = layers.BatchNormalization()(x)

    x = layers.Bidirectional(layers.LSTM(16, return_sequences=False,
                                         dropout=0.3, recurrent_dropout=0.3,
                                         kernel_regularizer=regularizers.l2(1e-3)))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.6)(x)

    # Dense layer dengan regularisasi L2 kuat
    x = layers.Dense(16, activation='relu',
                     kernel_regularizer=regularizers.l2(1e-3))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.7)(x)

    outputs = layers.Dense(2, activation='softmax')(x)
    return models.Model(inputs, outputs)

model = build_model((WINDOW, 4))
model.summary()

# Optimizer dengan learning rate standar (tanpa schedule)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# -------------------- 8. PELATIHAN (300 EPOCH, EARLY STOPPING, BATCH SIZE ADAPTIF) --------------------
os.makedirs('saved_model', exist_ok=True)
early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True, verbose=1)
checkpoint = callbacks.ModelCheckpoint('saved_model/best_model.keras', monitor='val_accuracy',
                                       save_best_only=True, verbose=1)
callbacks_list = [early_stop, checkpoint]

batch_size = min(32, len(X_train))
print(f"\n🚀 Memulai pelatihan dengan batch_size={batch_size}, epochs=300 (durasi ~6-10 menit)...")
start_time = time.time()
history = model.fit(X_train, y_train,
                    batch_size=batch_size,
                    epochs=300,
                    validation_split=0.2,
                    callbacks=callbacks_list,
                    verbose=1)
end_time = time.time()
print(f"✅ Pelatihan selesai dalam {(end_time - start_time)/60:.2f} menit.")

# Simpan model final dan scaler
model.save('saved_model/final_model.keras')
joblib.dump(scaler, 'saved_model/scaler.pkl')
print("✅ Model dan scaler disimpan di folder 'saved_model/'")

# -------------------- 9. EVALUASI DENGAN SKLEARN --------------------
y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Non-Coding', 'Coding'],
            yticklabels=['Non-Coding', 'Coding'])
plt.title('Confusion Matrix - Data Uji')
plt.ylabel('True Label'); plt.xlabel('Predicted Label')
plt.show()

print("\n📊 Classification Report (sklearn):")
print(classification_report(y_test, y_pred, target_names=['Non-Coding', 'Coding']))

# ROC Curve & AUC
fpr, tpr, _ = roc_curve(y_test, y_pred_proba[:,1])
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.3f})', linewidth=2)
plt.plot([0,1], [0,1], 'k--')
plt.xlabel('False Positive Rate'); plt.ylabel('True Positive Rate')
plt.title('ROC Curve'); plt.legend(); plt.grid(True)
plt.show()

precision, recall, f1, _ = precision_recall_fscore_support(y_test, y_pred, average='binary')
print(f"\n📈 Metrik tambahan (binary): Precision={precision:.3f}, Recall={recall:.3f}, F1={f1:.3f}, AUC={roc_auc:.3f}")

# Kurva training (akurasi dan loss)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(history.history['accuracy'], label='Train Acc')
axes[0].plot(history.history['val_accuracy'], label='Val Acc')
axes[0].set_title('Akurasi selama training'); axes[0].legend(); axes[0].grid(True)
axes[1].plot(history.history['loss'], label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Loss selama training'); axes[1].legend(); axes[1].grid(True)
plt.tight_layout()
plt.show()

# Gap analisis
gap = np.array(history.history['accuracy']) - np.array(history.history['val_accuracy'])
plt.figure(figsize=(8,4))
plt.plot(gap, color='red')
plt.axhline(y=0, color='black', linestyle='--')
plt.fill_between(range(len(gap)), 0, gap, where=(gap>0), alpha=0.3, color='red', label='Overfitting')
plt.fill_between(range(len(gap)), gap, 0, where=(gap<0), alpha=0.3, color='green', label='Underfitting')
plt.title('Gap Akurasi (Train - Validation)')
plt.xlabel('Epoch'); plt.ylabel('Gap'); plt.legend(); plt.grid(True)
plt.show()

final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
gap_acc = final_train_acc - final_val_acc
if gap_acc > 0.1:
    diagnosis = "⚠️ OVERFITTING (gap > 0.1) - Perlu regularisasi lebih kuat"
elif gap_acc < -0.05:
    diagnosis = "⚠️ UNDERFITTING (gap negatif) - Perlu kapasitas model lebih besar"
else:
    diagnosis = "✅ WELL-FITTED - Model generalisasi baik"

print("\n" + "="*50)
print("📋 RINGKASAN KINERJA MODEL (Standar Jurnal Internasional)")
print("="*50)
print(f"Train Accuracy      : {final_train_acc:.4f}")
print(f"Validation Accuracy : {final_val_acc:.4f}")
print(f"Gap (Train - Val)   : {gap_acc:.4f}")
print(f"Test Accuracy       : {(y_pred == y_test).mean():.4f}")
print(f"Test Precision      : {precision:.3f}")
print(f"Test Recall         : {recall:.3f}")
print(f"Test F1-Score       : {f1:.3f}")
print(f"Test AUC            : {roc_auc:.3f}")
print(f"Mode Dataset        : {mode}")
print(f"Diagnosis           : {diagnosis}")
print(f"Total waktu training: {(end_time - start_time)/60:.2f} menit")
print("="*50)

# -------------------- 10. DEPLOYMENT SEDERHANA (5 KASUS UJI) --------------------
print("\n" + "="*60)
print("🚀 DEPLOYMENT – PENGUJIAN MODEL DENGAN DATA BARU")
print("="*60)

try:
    deployed_model = tf.keras.models.load_model('saved_model/best_model.keras')
    deployed_scaler = joblib.load('saved_model/scaler.pkl')
    print("✅ Model dan scaler dimuat ulang dari penyimpanan.")
except:
    deployed_model = model
    deployed_scaler = scaler
    print("⚠️ Menggunakan model dari memori.")

def predict_new_sequence(seq, model, scaler, window=1000, stride=500):
    seq = validate_sequence(seq)
    if len(seq) < window:
        raise ValueError(f"Sekuens terlalu pendek ({len(seq)} bp), minimal {window} bp.")
    windows = sliding_windows(seq, window, stride)
    n_win = windows.shape[0]
    flat = windows.reshape(n_win, -1)
    scaled = scaler.transform(flat)
    scaled = scaled.reshape(n_win, window, 4)
    probs = model.predict(scaled, verbose=0)
    avg_prob_coding = np.mean(probs[:, 1])
    pred_class = 1 if avg_prob_coding > 0.5 else 0
    return pred_class, avg_prob_coding

test_cases = [
    ("GC-rich (tinggi)", "GCGCGCGCGC" * 100 + "ATATATATAT" * 50),
    ("AT-rich (rendah)", "ATATATATAT" * 150),
    ("Random komposisi mitokondria",
     ''.join(np.random.choice(['A','T','C','G'], size=1200, p=[0.3254,0.2582,0.2759,0.1405]))),
    ("Wilayah awal genom asli", sequence[:1200] if len(sequence)>=1200 else synthetic_sequence(1200)),
    ("Kodon tiruan (ATG...TAA)", "ATG" * 400 + "TAA")
]

results = []
print("\n📋 Hasil Prediksi untuk 5 Data Uji:")
for name, seq_test in test_cases:
    try:
        pred, prob = predict_new_sequence(seq_test, deployed_model, deployed_scaler, WINDOW, STRIDE)
        label_str = "Coding (1)" if pred == 1 else "Non-Coding (0)"
        results.append({"Nama Kasus": name, "Panjang (bp)": len(seq_test),
                        "Prediksi": label_str, "Prob. Coding": f"{prob:.4f}"})
        print(f"  ✅ {name}: {label_str} (prob coding = {prob:.4f})")
    except Exception as e:
        print(f"  ❌ {name}: Error - {e}")

df_test = pd.DataFrame(results)
print("\n📊 Tabel Ringkasan Prediksi Deployment:")
print(df_test.to_string(index=False))

plt.figure(figsize=(10,5))
names_plot = [r["Nama Kasus"] for r in results]
probs_plot = [float(r["Prob. Coding"]) for r in results]
colors = ['red' if p<0.5 else 'green' for p in probs_plot]
plt.barh(names_plot, probs_plot, color=colors)
plt.axvline(x=0.5, color='black', linestyle='--', label='Threshold 0.5')
plt.xlabel('Probabilitas Coding')
plt.title('Hasil Prediksi Deployment pada 5 Data Uji')
plt.xlim(0,1)
plt.legend()
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

df_test.to_csv('saved_model/deployment_results.csv', index=False)
print("\n💾 Hasil deployment disimpan di 'saved_model/deployment_results.csv'")
print("\n✅ Program selesai dijalankan dengan integritas dan konsistensi penuh.")
# Out:
# ✅ Lingkungan siap | TensorFlow version: 2.19.0
#
# ============================================================
# 📥 LOAD DATASET DARI NCBI
# URL: https://www.ncbi.nlm.nih.gov/nuccore/KX129904
# ============================================================
#
# Pilih mode pengambilan data:
# 1️⃣  Mode Cepat (FASTA only) → label berdasarkan GC content
# 2️⃣  Mode Lengkap (FASTA + Anotasi) → label berdasarkan CDS (DIREKOMENDASIKAN)
# 3️⃣  Mode Offline (Fallback) → data sintetis
#
# 🔹 Mode 1: Mengambil FASTA...
# ✅ Sekuens valid, panjang = 16567 bp
#
# 📌 Metode label yang digunakan: gc
#
# ============================================================
# 📊 EKSPLORASI DATA AWAL (EDA)
# ============================================================
# Distribusi kelas awal: 0=16, 1=16
# Total data setelah augmentasi (reverse complement + random sub): 128 sampel
# Distribusi label: 0=64, 1=64
# Data sudah seimbang, SMOTE tidak diperlukan.
# Data latih: 102, data uji: 26
# Label latih: 0=51, 1=51
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 1000, 4)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 1000, 32)       │           672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 1000, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 500, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 500, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 500, 64)        │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 500, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 250, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 250, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_8 (Bidirectional) │ (None, 250, 64)        │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 250, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_9 (Bidirectional) │ (None, 32)             │        10,368 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 2)              │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 43,474 (169.82 KB)
#  Trainable params: 43,058 (168.20 KB)
#  Non-trainable params: 416 (1.62 KB)
# 🚀 Memulai pelatihan dengan batch_size=32, epochs=300 (durasi ~6-10 menit)...
# Epoch 1/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4916 - loss: 2.0339
# Epoch 1: val_accuracy improved from None to 0.38095, saving model to saved_model/best_model.keras
#
# Epoch 1: finished saving model to saved_model/best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.5062 - loss: 2.0671 - val_accuracy: 0.3810 - val_loss: 1.1271
# Epoch 2/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4864 - loss: 1.9731
# Epoch 2: val_accuracy did not improve from 0.38095
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5062 - loss: 1.7907 - val_accuracy: 0.3810 - val_loss: 1.1156
# Epoch 3/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4771 - loss: 1.9661
# Epoch 3: val_accuracy did not improve from 0.38095
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4938 - loss: 1.8444 - val_accuracy: 0.3810 - val_loss: 1.1023
# Epoch 4/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4801 - loss: 2.0910
# Epoch 4: val_accuracy did not improve from 0.38095
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5185 - loss: 2.0361 - val_accuracy: 0.3810 - val_loss: 1.0945
# Epoch 5/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4990 - loss: 1.9582
# Epoch 5: val_accuracy improved from 0.38095 to 0.42857, saving model to saved_model/best_model.keras
#
# Epoch 5: finished saving model to saved_model/best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4815 - loss: 2.0161 - val_accuracy: 0.4286 - val_loss: 1.0889
# Epoch 6/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4335 - loss: 2.0744
# Epoch 6: val_accuracy did not improve from 0.42857
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4568 - loss: 1.9739 - val_accuracy: 0.4286 - val_loss: 1.0867
# Epoch 7/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4075 - loss: 1.9552
# Epoch 7: val_accuracy did not improve from 0.42857
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4568 - loss: 1.8770 - val_accuracy: 0.3810 - val_loss: 1.0845
# Epoch 8/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4365 - loss: 1.9710
# Epoch 8: val_accuracy did not improve from 0.42857
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4815 - loss: 1.9282 - val_accuracy: 0.4286 - val_loss: 1.0811
# Epoch 9/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4533 - loss: 2.0785
# Epoch 9: val_accuracy improved from 0.42857 to 0.47619, saving model to saved_model/best_model.keras
#
# Epoch 9: finished saving model to saved_model/best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4691 - loss: 2.0382 - val_accuracy: 0.4762 - val_loss: 1.0788
# Epoch 10/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5240 - loss: 1.8780
# Epoch 10: val_accuracy did not improve from 0.47619
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4938 - loss: 1.9385 - val_accuracy: 0.4762 - val_loss: 1.0741
# Epoch 11/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4958 - loss: 1.8335
# Epoch 11: val_accuracy did not improve from 0.47619
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5185 - loss: 1.8389 - val_accuracy: 0.4762 - val_loss: 1.0700
# Epoch 12/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5270 - loss: 2.1468
# Epoch 12: val_accuracy improved from 0.47619 to 0.57143, saving model to saved_model/best_model.keras
#
# Epoch 12: finished saving model to saved_model/best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5185 - loss: 2.1360 - val_accuracy: 0.5714 - val_loss: 1.0664
# Epoch 13/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4678 - loss: 1.6499
# Epoch 13: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4815 - loss: 1.6520 - val_accuracy: 0.5238 - val_loss: 1.0623
# Epoch 14/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3526 - loss: 2.2746
# Epoch 14: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.3704 - loss: 2.1755 - val_accuracy: 0.5238 - val_loss: 1.0585
# Epoch 15/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4730 - loss: 1.8616
# Epoch 15: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4815 - loss: 1.8202 - val_accuracy: 0.5238 - val_loss: 1.0567
# Epoch 16/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5572 - loss: 2.0214
# Epoch 16: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5309 - loss: 1.9268 - val_accuracy: 0.4286 - val_loss: 1.0549
# Epoch 17/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5136 - loss: 1.9666
# Epoch 17: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4938 - loss: 2.0683 - val_accuracy: 0.4762 - val_loss: 1.0538
# Epoch 18/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4774 - loss: 1.6428
# Epoch 18: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4321 - loss: 1.7114 - val_accuracy: 0.4762 - val_loss: 1.0524
# Epoch 19/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5114 - loss: 1.7743
# Epoch 19: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5185 - loss: 1.6981 - val_accuracy: 0.4762 - val_loss: 1.0520
# Epoch 20/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4741 - loss: 1.7857
# Epoch 20: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4691 - loss: 1.7299 - val_accuracy: 0.4762 - val_loss: 1.0513
# Epoch 21/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5561 - loss: 1.6891
# Epoch 21: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5432 - loss: 1.6006 - val_accuracy: 0.4762 - val_loss: 1.0510
# Epoch 22/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5270 - loss: 1.8418
# Epoch 22: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5185 - loss: 1.8034 - val_accuracy: 0.4286 - val_loss: 1.0514
# Epoch 23/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5717 - loss: 1.5213
# Epoch 23: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5432 - loss: 1.5351 - val_accuracy: 0.4762 - val_loss: 1.0509
# Epoch 24/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6216 - loss: 1.6141
# Epoch 24: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5679 - loss: 1.7537 - val_accuracy: 0.5714 - val_loss: 1.0494
# Epoch 25/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3337 - loss: 2.0954
# Epoch 25: val_accuracy did not improve from 0.57143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4074 - loss: 1.8821 - val_accuracy: 0.5714 - val_loss: 1.0478
# Epoch 26/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4637 - loss: 1.9508
# Epoch 26: val_accuracy improved from 0.57143 to 0.61905, saving model to saved_model/best_model.keras
#
# Epoch 26: finished saving model to saved_model/best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4691 - loss: 1.8572 - val_accuracy: 0.6190 - val_loss: 1.0464
# Epoch 27/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4077 - loss: 1.8583
# Epoch 27: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.3951 - loss: 1.8046 - val_accuracy: 0.6190 - val_loss: 1.0452
# Epoch 28/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5676 - loss: 1.4631
# Epoch 28: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5309 - loss: 1.6040 - val_accuracy: 0.6190 - val_loss: 1.0430
# Epoch 29/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4990 - loss: 1.9163
# Epoch 29: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4815 - loss: 1.9660 - val_accuracy: 0.6190 - val_loss: 1.0404
# Epoch 30/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5062 - loss: 1.6151
# Epoch 30: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5185 - loss: 1.6981 - val_accuracy: 0.6190 - val_loss: 1.0389
# Epoch 31/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4823 - loss: 1.9652
# Epoch 31: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4938 - loss: 1.8181 - val_accuracy: 0.6190 - val_loss: 1.0373
# Epoch 32/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3858 - loss: 1.9865
# Epoch 32: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4074 - loss: 1.8598 - val_accuracy: 0.6190 - val_loss: 1.0366
# Epoch 33/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4908 - loss: 1.6585
# Epoch 33: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4568 - loss: 1.7640 - val_accuracy: 0.6190 - val_loss: 1.0352
# Epoch 34/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5509 - loss: 1.4895
# Epoch 34: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5432 - loss: 1.6070 - val_accuracy: 0.6190 - val_loss: 1.0339
# Epoch 35/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4541 - loss: 1.7465
# Epoch 35: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5185 - loss: 1.6280 - val_accuracy: 0.6190 - val_loss: 1.0328
# Epoch 36/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5311 - loss: 1.6418
# Epoch 36: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5309 - loss: 1.6546 - val_accuracy: 0.6190 - val_loss: 1.0322
# Epoch 37/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5229 - loss: 1.4011
# Epoch 37: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5062 - loss: 1.3931 - val_accuracy: 0.6190 - val_loss: 1.0322
# Epoch 38/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4409 - loss: 1.7169
# Epoch 38: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4321 - loss: 1.7919 - val_accuracy: 0.6190 - val_loss: 1.0326
# Epoch 39/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5251 - loss: 1.8900
# Epoch 39: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4815 - loss: 2.0065 - val_accuracy: 0.6190 - val_loss: 1.0328
# Epoch 40/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4958 - loss: 1.4090
# Epoch 40: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5185 - loss: 1.3990 - val_accuracy: 0.6190 - val_loss: 1.0330
# Epoch 41/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5095 - loss: 1.8293
# Epoch 41: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4815 - loss: 1.7873 - val_accuracy: 0.6190 - val_loss: 1.0331
# Epoch 42/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5166 - loss: 1.4530
# Epoch 42: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5185 - loss: 1.5543 - val_accuracy: 0.6190 - val_loss: 1.0331
# Epoch 43/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4179 - loss: 1.5760
# Epoch 43: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4568 - loss: 1.5668 - val_accuracy: 0.6190 - val_loss: 1.0330
# Epoch 44/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4968 - loss: 1.4990
# Epoch 44: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5062 - loss: 1.4217 - val_accuracy: 0.6190 - val_loss: 1.0329
# Epoch 45/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5248 - loss: 1.3338
# Epoch 45: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5432 - loss: 1.3806 - val_accuracy: 0.6190 - val_loss: 1.0327
# Epoch 46/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6112 - loss: 1.3354
# Epoch 46: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5679 - loss: 1.3720 - val_accuracy: 0.6190 - val_loss: 1.0322
# Epoch 47/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4543 - loss: 1.7564
# Epoch 47: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4568 - loss: 1.7488 - val_accuracy: 0.6190 - val_loss: 1.0319
# Epoch 48/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4346 - loss: 1.7390
# Epoch 48: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4444 - loss: 1.6921 - val_accuracy: 0.6190 - val_loss: 1.0320
# Epoch 49/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4335 - loss: 1.7120
# Epoch 49: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4568 - loss: 1.6225 - val_accuracy: 0.6190 - val_loss: 1.0316
# Epoch 50/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6186 - loss: 1.4424
# Epoch 50: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5432 - loss: 1.5923 - val_accuracy: 0.6190 - val_loss: 1.0316
# Epoch 51/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5311 - loss: 1.5878
# Epoch 51: val_accuracy did not improve from 0.61905
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5309 - loss: 1.5464 - val_accuracy: 0.6190 - val_loss: 1.0322
# Epoch 52/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4417 - loss: 1.6797
# Epoch 52: val_accuracy improved from 0.61905 to 0.66667, saving model to saved_model/best_model.keras
#
# Epoch 52: finished saving model to saved_model/best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4815 - loss: 1.6702 - val_accuracy: 0.6667 - val_loss: 1.0327
# Epoch 53/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4960 - loss: 1.4989
# Epoch 53: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4568 - loss: 1.6708 - val_accuracy: 0.6667 - val_loss: 1.0327
# Epoch 54/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4782 - loss: 1.5944
# Epoch 54: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4815 - loss: 1.6216 - val_accuracy: 0.6190 - val_loss: 1.0334
# Epoch 55/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4979 - loss: 1.5434
# Epoch 55: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4938 - loss: 1.5591 - val_accuracy: 0.5714 - val_loss: 1.0350
# Epoch 56/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5635 - loss: 1.3759
# Epoch 56: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5185 - loss: 1.3892 - val_accuracy: 0.5238 - val_loss: 1.0361
# Epoch 57/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5292 - loss: 1.5272
# Epoch 57: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4938 - loss: 1.5145 - val_accuracy: 0.5714 - val_loss: 1.0374
# Epoch 58/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5177 - loss: 1.3887
# Epoch 58: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5062 - loss: 1.3973 - val_accuracy: 0.5714 - val_loss: 1.0389
# Epoch 59/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4242 - loss: 1.4954
# Epoch 59: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4444 - loss: 1.4961 - val_accuracy: 0.5714 - val_loss: 1.0394
# Epoch 60/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4283 - loss: 1.5371
# Epoch 60: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.4568 - loss: 1.4314 - val_accuracy: 0.5714 - val_loss: 1.0399
# Epoch 61/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5728 - loss: 1.3162
# Epoch 61: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5309 - loss: 1.3100 - val_accuracy: 0.5238 - val_loss: 1.0408
# Epoch 62/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5437 - loss: 1.5613
# Epoch 62: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5062 - loss: 1.6440 - val_accuracy: 0.5238 - val_loss: 1.0422
# Epoch 63/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5602 - loss: 1.6431
# Epoch 63: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5556 - loss: 1.5052 - val_accuracy: 0.5238 - val_loss: 1.0431
# Epoch 64/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4988 - loss: 1.4519
# Epoch 64: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5432 - loss: 1.3235 - val_accuracy: 0.5238 - val_loss: 1.0446
# Epoch 65/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4999 - loss: 1.3622
# Epoch 65: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5309 - loss: 1.2908 - val_accuracy: 0.5238 - val_loss: 1.0467
# Epoch 66/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5966 - loss: 1.3023
# Epoch 66: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5556 - loss: 1.2989 - val_accuracy: 0.5238 - val_loss: 1.0482
# Epoch 67/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4749 - loss: 1.5781
# Epoch 67: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.5185 - loss: 1.4718 - val_accuracy: 0.5238 - val_loss: 1.0495
# Epoch 68/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5975 - loss: 1.2230
# Epoch 68: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.6049 - loss: 1.2448 - val_accuracy: 0.5238 - val_loss: 1.0501
# Epoch 69/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5446 - loss: 1.5284
# Epoch 69: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5556 - loss: 1.3814 - val_accuracy: 0.5238 - val_loss: 1.0497
# Epoch 70/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4108 - loss: 1.6930
# Epoch 70: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4198 - loss: 1.6563 - val_accuracy: 0.5238 - val_loss: 1.0504
# Epoch 71/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5133 - loss: 1.6184
# Epoch 71: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.5556 - loss: 1.4766 - val_accuracy: 0.5238 - val_loss: 1.0504
# Epoch 72/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4722 - loss: 1.5652
# Epoch 72: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4321 - loss: 1.6345 - val_accuracy: 0.5238 - val_loss: 1.0506
# Epoch 73/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5363 - loss: 1.3188
# Epoch 73: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.5309 - loss: 1.2921 - val_accuracy: 0.5238 - val_loss: 1.0501
# Epoch 74/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5084 - loss: 1.7914
# Epoch 74: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - accuracy: 0.4938 - loss: 1.7001 - val_accuracy: 0.5238 - val_loss: 1.0504
# Epoch 75/300
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4990 - loss: 1.4677
# Epoch 75: val_accuracy did not improve from 0.66667
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 4s/step - accuracy: 0.4815 - loss: 1.4805 - val_accuracy: 0.4762 - val_loss: 1.0512
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 50.
# ✅ Pelatihan selesai dalam 12.29 menit.
# ✅ Model dan scaler disimpan di folder 'saved_model/'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 📊 Classification Report (sklearn):
#               precision    recall  f1-score   support
#
#   Non-Coding       0.50      0.77      0.61        13
#       Coding       0.50      0.23      0.32        13
#
#     accuracy                           0.50        26
#    macro avg       0.50      0.50      0.46        26
# weighted avg       0.50      0.50      0.46        26
# 📈 Metrik tambahan (binary): Precision=0.500, Recall=0.231, F1=0.316, AUC=0.562
# ==================================================
# 📋 RINGKASAN KINERJA MODEL (Standar Jurnal Internasional)
# ==================================================
# Train Accuracy      : 0.4815
# Validation Accuracy : 0.4762
# Gap (Train - Val)   : 0.0053
# Test Accuracy       : 0.5000
# Test Precision      : 0.500
# Test Recall         : 0.231
# Test F1-Score       : 0.316
# Test AUC            : 0.562
# Mode Dataset        : 1
# Diagnosis           : ✅ WELL-FITTED - Model generalisasi baik
# Total waktu training: 12.29 menit
# ==================================================
#
# ============================================================
# 🚀 DEPLOYMENT – PENGUJIAN MODEL DENGAN DATA BARU
# ============================================================
# ✅ Model dan scaler dimuat ulang dari penyimpanan.
#
# 📋 Hasil Prediksi untuk 5 Data Uji:
#   ✅ GC-rich (tinggi): Non-Coding (0) (prob coding = 0.4226)
#   ✅ AT-rich (rendah): Non-Coding (0) (prob coding = 0.4983)
#   ✅ Random komposisi mitokondria: Non-Coding (0) (prob coding = 0.4685)
#   ✅ Wilayah awal genom asli: Non-Coding (0) (prob coding = 0.3860)
#   ✅ Kodon tiruan (ATG...TAA): Coding (1) (prob coding = 0.5181)
#
# 📊 Tabel Ringkasan Prediksi Deployment:
#                   Nama Kasus  Panjang (bp)       Prediksi Prob. Coding
#             GC-rich (tinggi)          1500 Non-Coding (0)       0.4226
#             AT-rich (rendah)          1500 Non-Coding (0)       0.4983
# Random komposisi mitokondria          1200 Non-Coding (0)       0.4685
#      Wilayah awal genom asli          1200 Non-Coding (0)       0.3860
#     Kodon tiruan (ATG...TAA)          1203     Coding (1)       0.5181
# 💾 Hasil deployment disimpan di 'saved_model/deployment_results.csv'
#
# ✅ Program selesai dijalankan dengan integritas dan konsistensi penuh.
